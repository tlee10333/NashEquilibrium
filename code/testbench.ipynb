# %%
from WS import Network
import networkx as nx

x = Network(15, 3, 0.2)
x.draw()

# %%
x.round()
x.update()

for a in range(10):

    x.round()
    print(x.nash_pair(6))
    x.update()
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
x.round()
print(x.prisoner_list[0].get_payoff())

for i in x.get_neighbors(0):
    print(x.prisoner_list[i].get_strategy())
    print(x.prisoner_list[i].get_payoff())
# Out:
# 0
# D
# 0
# D
# 0
# D
# 0

# %%
x.update()

print(x.prisoner_list[0].get_strategy())
print(x.prisoner_list[0].get_payoff())  # should be 0
# Out:
# D
# 0

# %%
y.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_38969/492155887.py in <module>
# ----> 1 y.draw()
#
# NameError: name 'y' is not defined
